# %%
#Load Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker 
import folium 
import seaborn as sns 
import pycountry_convert as pyc
import datetime as dt 
import plotly.express as px
# %matplotlib inline

# %%
us_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv')

us_cases.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1  22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2  51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3  16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4  19001.0      Adair            Iowa             US  2020-04-01 21:58:49
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       0
# 1  30.295065  -92.414197         47       1          0       0
# 2  37.767072  -75.632346          7       0          0       0
# 3  43.452658 -116.241552        195       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# 3                 Ada, Idaho, US
# 4                Adair, Iowa, US

# %%
us_cases.shape
# Out:
# (2485, 12)

# %%
us_cases = us_cases.loc[us_cases['Country_Region'] == 'US']
us_cases.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1  22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2  51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3  16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4  19001.0      Adair            Iowa             US  2020-04-01 21:58:49
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       0
# 1  30.295065  -92.414197         47       1          0       0
# 2  37.767072  -75.632346          7       0          0       0
# 3  43.452658 -116.241552        195       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# 3                 Ada, Idaho, US
# 4                Adair, Iowa, US

# %%
us_cases.shape
# Out:
# (2230, 12)

# %%
#Let drop and rename columns 

usa_df = us_cases.drop(['Combined_Key', 'FIPS'], axis=1)

usa_df.head()
# Out:
#       Admin2  Province_State Country_Region          Last_Update        Lat  \
# 0  Abbeville  South Carolina             US  2020-04-01 21:58:49  34.223334
# 1     Acadia       Louisiana             US  2020-04-01 21:58:49  30.295065
# 2   Accomack        Virginia             US  2020-04-01 21:58:49  37.767072
# 3        Ada           Idaho             US  2020-04-01 21:58:49  43.452658
# 4      Adair            Iowa             US  2020-04-01 21:58:49  41.330756
#
#         Long_  Confirmed  Deaths  Recovered  Active
# 0  -82.461707          4       0          0       0
# 1  -92.414197         47       1          0       0
# 2  -75.632346          7       0          0       0
# 3 -116.241552        195       3          0       0
# 4  -94.471059          1       0          0       0

# %%
usa_df_clean = usa_df.rename(columns={'Admin2': 'City',
                      'Province_State': 'State'})


usa_df_clean.head()
# Out:
#         City           State Country_Region          Last_Update        Lat  \
# 0  Abbeville  South Carolina             US  2020-04-01 21:58:49  34.223334
# 1     Acadia       Louisiana             US  2020-04-01 21:58:49  30.295065
# 2   Accomack        Virginia             US  2020-04-01 21:58:49  37.767072
# 3        Ada           Idaho             US  2020-04-01 21:58:49  43.452658
# 4      Adair            Iowa             US  2020-04-01 21:58:49  41.330756
#
#         Long_  Confirmed  Deaths  Recovered  Active
# 0  -82.461707          4       0          0       0
# 1  -92.414197         47       1          0       0
# 2  -75.632346          7       0          0       0
# 3 -116.241552        195       3          0       0
# 4  -94.471059          1       0          0       0

# %%
usa_df_clean['City_State'] = usa_df_clean['City'] + ", " + usa_df_clean['State']

usa_df_clean.head()
# Out:
#         City           State Country_Region          Last_Update        Lat  \
# 0  Abbeville  South Carolina             US  2020-04-01 21:58:49  34.223334
# 1     Acadia       Louisiana             US  2020-04-01 21:58:49  30.295065
# 2   Accomack        Virginia             US  2020-04-01 21:58:49  37.767072
# 3        Ada           Idaho             US  2020-04-01 21:58:49  43.452658
# 4      Adair            Iowa             US  2020-04-01 21:58:49  41.330756
#
#         Long_  Confirmed  Deaths  Recovered  Active                 City_State
# 0  -82.461707          4       0          0       0  Abbeville, South Carolina
# 1  -92.414197         47       1          0       0          Acadia, Louisiana
# 2  -75.632346          7       0          0       0         Accomack, Virginia
# 3 -116.241552        195       3          0       0                 Ada, Idaho
# 4  -94.471059          1       0          0       0                Adair, Iowa

# %%
#Let see the total confirmed and deaths as of 4/2/2020 

total_sum = usa_df_clean.sum()

total_df = pd.DataFrame(total_sum).transpose().loc[:,['Confirmed','Deaths']]

total_df['Mortality Rate in US (%)'] = np.round(total_df['Deaths']/total_df['Confirmed'] * 100,2)

total_df
# Out:
#    Confirmed  Deaths  Mortality Rate in US (%)
# 0   213372.0  4757.0                      2.23

# %%
# usa_df_clean= usa_df_clean.drop(['Country_Region', 'Last_Update', 'Lat', 'Long_', 'Recovered', 'Active', 'City', 'State'], axis=1)
#Created a DF with top 10 cities based on number of deaths 
top_ten_df = usa_df_clean.sort_values('Deaths', ascending=False)[:11].set_index('City_State')

top_ten_df.style.background_gradient(cmap='OrRd')
#Dropped the second NY Row since it had an unassigned city 

i = top_ten_df[top_ten_df['Confirmed'] == 0].index

# top_ten_mort = top_ten_df.drop(i)
top_ten_mort
# Out:
#                          Confirmed  Deaths  Mortality Rate %
# City_State
# New York City, New York      47439    1139              2.40
# King, Washington              2330     150              6.44
# Wayne, Michigan               4470     146              3.27
# Orleans, Louisiana            2270     115              5.07
# Oakland, Michigan             1910      99              5.18
# Cook, Illinois                5152      95              1.84
# Nassau, New York              9554      76              0.80
# Bergen, New Jersey            3494      75              2.15
# Essex, New Jersey             2262      69              3.05
# Jefferson, Louisiana          1433      64              4.47

# %%
fig = plt.figure(figsize=(12,6))
plt.xlim(.5, 7)
plt.barh(top_ten_mort.sort_values('Mortality Rate %')['Mortality Rate %'].index,
         top_ten_mort.sort_values('Mortality Rate %')['Mortality Rate %'].values)
plt.title("States with the Highest Mortality Rate", fontsize=16)
plt.xlabel('Mortality Rate %', fontsize=12)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
fig.add_subplot()
plt.xlim(50,1500)

plt.barh(top_ten_df.sort_values('Deaths')['Deaths'].index,
         top_ten_df.sort_values('Deaths')['Deaths'].values, color='firebrick')

plt.title('US States with the Most Casualties', fontsize=16)
plt.xlabel('Number of Deaths', fontsize=12)
plt.show()

# %%
#Top 10 states with high mortality rates, with at least 1000 confirmed cases 
usa_df_clean['Mortality Rate %'] = np.round(usa_df_clean['Deaths']/usa_df_clean['Confirmed'] * 100, 2)
high_mortality = usa_df_clean.loc[usa_df_clean['Mortality Rate %'] > 2.23]
top_10_mortality = high_mortality.sort_values('Confirmed', ascending=False)
top_10_mortality
# Out:
#       Confirmed  Deaths               City_State  Mortality Rate %
# 1436      47439    1139  New York City, New York              2.40
# 2116       4470     146          Wayne, Michigan              3.27
# 1041       2330     150         King, Washington              6.44
# 1500       2270     115       Orleans, Louisiana              5.07
# 634        2262      69        Essex, New Jersey              3.05
# 641        1986      46   Fairfield, Connecticut              2.32
# 1465       1910      99        Oakland, Michigan              5.18
# 978        1433      64     Jefferson, Louisiana              4.47
# 1813       1304      40    Snohomish, Washington              3.07
# 1205       1088      51         Macomb, Michigan              4.69
# 386         961      28            Clark, Nevada              2.91
# 1745        956      32  Santa Clara, California              3.35
# 1398        942      25       Morris, New Jersey              2.65
# 710         624      19          Fulton, Georgia              3.04
# 1433        611      15   New Haven, Connecticut              2.45
# 1532        567      14      Palm Beach, Florida              2.47
# 578         480      27       Dougherty, Georgia              5.62
# 818         475      16   Hampden, Massachusetts              3.37
# 1819        472      15     Somerset, New Jersey              3.18
# 848         469      11    Hartford, Connecticut              2.35
# 2001        442      11    Unassigned, Tennessee              2.49
# 590         392      12         DuPage, Illinois              3.06
# 1736        388      10    San Mateo, California              2.58
# 1680        371      13    Riverside, California              3.50
# 1360        349       9         Monroe, New York              2.58
# 2161        322       9           Will, Illinois              2.80
# 18          313       7      Alameda, California              2.24
# 241         298       7         Caddo, Louisiana              2.35
# 427         293      15            Cobb, Georgia              5.12
# 617         286      13        El Paso, Colorado              4.55
# ...         ...     ...                      ...               ...
# 2065          2       1          Warren, Indiana             50.00
# 746           2       1        Gogebic, Michigan             50.00
# 1250          2       1   Marion, South Carolina             50.00
# 1781          2       1       Sequoyah, Oklahoma             50.00
# 2157          2       1   Wilkes, North Carolina             50.00
# 1483          2       1            Oldham, Texas             50.00
# 175           2       1        Bourbon, Kentucky             50.00
# 793           2       1          Greer, Oklahoma             50.00
# 2032          2       1         Van Zandt, Texas             50.00
# 2113          2       1       Waupaca, Wisconsin             50.00
# 202           2       1              Brown, Ohio             50.00
# 43            2       1       Anderson, Kentucky             50.00
# 1339          1       1      Missaukee, Michigan            100.00
# 867           1       1          Henry, Missouri            100.00
# 1763          1       1           Scott, Indiana            100.00
# 1288          1       1    McHenry, North Dakota            100.00
# 718           1       1             Gallia, Ohio            100.00
# 933           1       1          Iron, Wisconsin            100.00
# 496           1       1        Crowley, Colorado            100.00
# 459           1       1         Conway, Arkansas            100.00
# 307           1       1            Cassia, Idaho            100.00
# 1985          0       1         Unassigned, Iowa               inf
# 1975          0       2       Unassigned, Alaska               inf
# 1976          0      18      Unassigned, Arizona               inf
# 2003          0      19     Unassigned, Virginia               inf
# 1978          0       1   Unassigned, California               inf
# 1999          0       1     Unassigned, Oklahoma               inf
# 1998          0     565     Unassigned, New York               inf
# 1989          0      12     Unassigned, Maryland               inf
# 1992          0       8    Unassigned, Minnesota               inf
#
# [379 rows x 4 columns]

# %%
top_ten_conf = usa_df_clean.sort_values('Confirmed', ascending= False).set_index('City_State')[:10]
top_ten_conf.style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
#     #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col0 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col1 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col2 {
#             background-color:  #da3724;
#             color:  #f1f1f1;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col0 {
#             background-color:  #fee2bb;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col1 {
#             background-color:  #fff5e6;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col2 {
#             background-color:  #feefd8;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col0 {
#             background-color:  #fee5c3;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col1 {
#             background-color:  #feefd9;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col2 {
#             background-color:  #fdd5a0;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col0 {
#             background-color:  #feecd1;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col1 {
#             background-color:  #fff2e0;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col2 {
#             background-color:  #fddaab;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col0 {
#             background-color:  #fff2e1;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col1 {
#             background-color:  #feedd4;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col2 {
#             background-color:  #f57850;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col0 {
#             background-color:  #fff4e5;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col2 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow6_col0 {
#             background-color:  #fff4e5;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow6_col1 {
#             background-color:  #fee8c8;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow6_col2 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow7_col0 {
#             background-color:  #fff7eb;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow7_col1 {
#             background-color:  #fff0dc;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow7_col2 {
#             background-color:  #f67b51;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow8_col0 {
#             background-color:  #fff7eb;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow8_col1 {
#             background-color:  #feefda;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow8_col2 {
#             background-color:  #e9573d;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow9_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow9_col1 {
#             background-color:  #fff5e7;
#             color:  #000000;
#         }    #T_647d5e1a_7607_11ea_8efe_802bf98fb16arow9_col2 {
#             background-color:  #fee2bb;
#             color:  #000000;
#         }</style><table id="T_647d5e1a_7607_11ea_8efe_802bf98fb16a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Mortality Rate %</th>    </tr>    <tr>        <th class="index_name level0" >City_State</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row0" class="row_heading level0 row0" >New York City, New York</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col0" class="data row0 col0" >47439</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col1" class="data row0 col1" >1139</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow0_col2" class="data row0 col2" >2.4</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row1" class="row_heading level0 row1" >Westchester, New York</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col0" class="data row1 col0" >10683</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col1" class="data row1 col1" >25</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow1_col2" class="data row1 col2" >0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row2" class="row_heading level0 row2" >Nassau, New York</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col0" class="data row2 col0" >9554</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col1" class="data row2 col1" >76</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow2_col2" class="data row2 col2" >0.8</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row3" class="row_heading level0 row3" >Suffolk, New York</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col0" class="data row3 col0" >7605</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col1" class="data row3 col1" >53</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow3_col2" class="data row3 col2" >0.7</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row4" class="row_heading level0 row4" >Cook, Illinois</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col0" class="data row4 col0" >5152</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col1" class="data row4 col1" >95</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow4_col2" class="data row4 col2" >1.84</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row5" class="row_heading level0 row5" >Unassigned, New Jersey</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col0" class="data row5 col0" >4512</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow5_col2" class="data row5 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_647d5e1a_7607_11ea_8efe_802bf98fb16alevel0_row6" class="row_heading level0 row6" >Wayne, Michigan</th>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow6_col0" class="data row6 col0" >4470</td>
#                         <td id="T_647d5e1a_7607_11ea_8efe_802bf98fb16arow6_col1" class="data row6 col1" >146</td>

# %%
plt.figure(figsize=(12,6))
plt.xlim(3000, 50000)

plt.barh(top_ten_conf.sort_values('Confirmed')['Confirmed'].index,
         top_ten_conf.sort_values('Confirmed')['Confirmed'].values)
plt.title('US States with the Most Confirmed Cases', fontsize=16)
plt.xlabel('Confirmed Cases', fontsize=12)
plt.show()
